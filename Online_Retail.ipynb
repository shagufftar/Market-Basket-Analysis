# %% [markdown]
# <a href="https://colab.research.google.com/github/roshank1605A04/Online-Retail-Transactions-of-UK/blob/master/Online_Retail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Online_Retail.csv', engine='python')
print(data.shape)
# Out:
# (541909, 8)

# %%
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
data.sample(5)
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 341853    566787     22686  ...        NaN  United Kingdom
# 456500    575694     21253  ...    12748.0  United Kingdom
# 162591    550512     21936  ...    18069.0  United Kingdom
# 232032    557299     23089  ...    13047.0  United Kingdom
# 402323    571496     23452  ...    13265.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
# describing the data
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# taking out information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# checking the data-types of the data
data.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
data = data[~data.duplicated()]

# %%
# checking if there is any NULL values present in the data
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
data1 = data.dropna()
data1
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [401604 rows x 8 columns]

# %%
# visualizing the unitprice
sns.distplot(data['UnitPrice'], color = 'lightblue')
plt.title('Distribution of Unit price', fontsize = 20)
plt.xlabel('Different Unit Price for different items')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# checking the different values for country in the dataset

data['Country'].value_counts().head(3).plot.bar(figsize = (10, 8))
plt.title('Top 3 Countries having Online Retail Market', fontsize = 20)
plt.xlabel('Names of Countries')
plt.ylabel('Count')
plt.show()

# %%
# checking how many quantity of products have been sold online from each country

data['Quantity'].groupby(data['Country']).agg('sum')
# Out:
# Country
# Australia                 83643
# Austria                    4827
# Bahrain                     260
# Belgium                   23152
# Brazil                      356
# Canada                     2763
# Channel Islands            9473
# Cyprus                     6296
# Czech Republic              592
# Denmark                    8188
# EIRE                     142495
# European Community          497
# Finland                   10666
# France                   110438
# Germany                  117341
# Greece                     1556
# Hong Kong                  4709
# Iceland                    2458
# Israel                     4350
# Italy                      7999
# Japan                     25218
# Lebanon                     386
# Lithuania                   652
# Malta                       944
# Netherlands              200128
# Norway                    19247
# Poland                     3653
# Portugal                  16153
# RSA                         352
# ...

# %%
# Having a look at the top 3 Countries in terms of Quantities according to the countries

data['Quantity'].groupby(data['Country']).agg('sum').sort_values(ascending = False).head(3).plot.bar(figsize = (10, 7))

plt.title('Top 3 Countries according to Quantity Sold Online', fontsize = 20)
plt.xlabel('Names of the Countries')
plt.ylabel('Number of Items Sold')
plt.show()

# %%
basket_UK = (data[data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket_UK
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES  ...  wrongly sold sets
# InvoiceNo                                    ...
# 536365                                  0.0  ...                0.0
# 536366                                  0.0  ...                0.0
# 536367                                  0.0  ...                0.0
# 536368                                  0.0  ...                0.0
# 536369                                  0.0  ...                0.0
# ...                                     ...  ...                ...
# C581484                                 0.0  ...                0.0
# C581490                                 0.0  ...                0.0
# C581499                                 0.0  ...                0.0
# C581568                                 0.0  ...                0.0
# C581569                                 0.0  ...                0.0
#
# [22040 rows x 4202 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_encoded = basket_UK.applymap(hot_encode)
basket_UK = basket_encoded

# %%
basket_UK_sets = basket_UK.applymap(hot_encode)
basket_UK_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_UK.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES  ...  wrongly sold sets
# InvoiceNo                                    ...
# 536365                                    0  ...                  0
# 536366                                    0  ...                  0
# 536367                                    0  ...                  0
# 536368                                    0  ...                  0
# 536369                                    0  ...                  0
#
# [5 rows x 4202 columns]

# %%
from mlxtend.frequent_patterns import apriori

UK_frequent_itemsets = apriori(basket_UK_sets, min_support=0.03, use_colnames=True)
UK_frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.038793                           (6 RIBBONS RUSTIC CHARM)
# 1   0.034165                      (60 TEATIME FAIRY CAKE CASES)
# 2   0.039746                       (ALARM CLOCK BAKELIKE GREEN)
# 3   0.042196                        (ALARM CLOCK BAKELIKE RED )
# 4   0.030672                     (ANTIQUE SILVER T-LIGHT GLASS)
# ..       ...                                                ...
# 82  0.048820                (WOODEN PICTURE FRAME WHITE FINISH)
# 83  0.030989                           (WOODLAND CHARLOTTE BAG)
# 84  0.031806  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 85  0.035617  (JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKA...
# 86  0.031670  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)
#
# [87 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

# %%
UK_rules = association_rules(UK_frequent_itemsets, metric="lift", min_threshold=1)
UK_rules.head()
# Out:
#                           antecedents  ... conviction
# 0  (ROSES REGENCY TEACUP AND SAUCER )  ...   3.579862
# 1   (GREEN REGENCY TEACUP AND SAUCER)  ...   3.834527
# 2           (JUMBO BAG RED RETROSPOT)  ...   1.592444
# 3           (JUMBO BAG PINK POLKADOT)  ...   2.826438
# 4           (JUMBO BAG RED RETROSPOT)  ...   1.482773
#
# [5 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = UK_rules)
plt.show()

# %%
UK_rules[ (UK_rules['lift'] >= 6) &
        (UK_rules['confidence'] >= 0.7)]
# Out:
#                           antecedents  ... conviction
# 0  (ROSES REGENCY TEACUP AND SAUCER )  ...   3.579862
# 1   (GREEN REGENCY TEACUP AND SAUCER)  ...   3.834527
#
# [2 rows x 9 columns]

# %%
pivot = UK_rules.pivot(index = 'consequents', columns = 'antecedents', values= 'lift')
sns.heatmap(pivot, annot = True, cbar=False)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
basket_GR = (data1[data1['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_GR.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                                    ...
# 536527                                  0.0  ...                               0.0
# 536840                                  0.0  ...                               0.0
# 536861                                  0.0  ...                               0.0
# 536967                                  0.0  ...                               0.0
# 536983                                  0.0  ...                               0.0
#
# [5 rows x 1703 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

basket_encoded = basket_GR.applymap(hot_encode)
basket_GR = basket_encoded

# %%
basket_GR_sets = basket_GR.applymap(hot_encode)
basket_GR_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_GR.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                                    ...
# 536527                                    0  ...                                 0
# 536840                                    0  ...                                 0
# 536861                                    0  ...                                 0
# 536967                                    0  ...                                 0
# 536983                                    0  ...                                 0
#
# [5 rows x 1703 columns]

# %%
from mlxtend.frequent_patterns import apriori

GR_frequent_itemsets = apriori(basket_GR_sets, min_support=0.05, use_colnames=True)
GR_frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.077944                           (6 RIBBONS RUSTIC CHARM)
# 1   0.053068                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.054726                                (GUMBALL COAT RACK)
# 3   0.069652                           (JAM MAKING SET PRINTED)
# 4   0.059701                          (JUMBO BAG RED RETROSPOT)
# 5   0.076285                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.059701                               (LUNCH BAG WOODLAND)
# 7   0.064677                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.087894                   (PLASTERS IN TIN CIRCUS PARADE )
# 9   0.081260                         (PLASTERS IN TIN SPACEBOY)
# 10  0.053068                        (PLASTERS IN TIN STRONGMAN)
# 11  0.104478                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.053068                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.053068                                (RED RETROSPOT CUP)
# ...

# %%
from mlxtend.frequent_patterns import association_rules

# %%
GR_rules = association_rules(GR_frequent_itemsets, metric="lift", min_threshold=1)
GR_rules.head()
# Out:
#                              antecedents  ... conviction
# 0       (PLASTERS IN TIN CIRCUS PARADE )  ...   2.157395
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)  ...   1.795709
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND )  ...   1.285878
# 3     (PLASTERS IN TIN WOODLAND ANIMALS)  ...   1.768914
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS )  ...   4.885572
#
# [5 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = GR_rules)
plt.show()

# %%
GR_rules[ (GR_rules['lift'] >= 15) &
        (GR_rules['confidence'] >= 0.2)]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
pivot = GR_rules.pivot(index = 'consequents', columns = 'antecedents', values= 'lift')
sns.heatmap(pivot, annot = True, cbar=False)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
FR_basket = (data1[data1['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

FR_basket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                                    ...
# 536370                                  0.0  ...                              0.0
# 536852                                  0.0  ...                              0.0
# 536974                                  0.0  ...                              0.0
# 537065                                  0.0  ...                              0.0
# 537463                                  0.0  ...                              0.0
#
# [5 rows x 1545 columns]

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
FR_basket_sets = FR_basket.applymap(encode_units)
FR_basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
FR_basket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                                    ...
# 536370                                  0.0  ...                              0.0
# 536852                                  0.0  ...                              0.0
# 536974                                  0.0  ...                              0.0
# 537065                                  0.0  ...                              0.0
# 537463                                  0.0  ...                              0.0
#
# [5 rows x 1545 columns]

# %%
FR_frequent_itemsets = apriori(FR_basket_sets, min_support=0.07, use_colnames=True)
FR_frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.082969                       (ALARM CLOCK BAKELIKE GREEN)
# 1   0.087336                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.080786                        (ALARM CLOCK BAKELIKE RED )
# 3   0.085153                             (DOLLY GIRL LUNCH BOX)
# 4   0.082969                          (JUMBO BAG RED RETROSPOT)
# 5   0.106987                           (LUNCH BAG APPLE DESIGN)
# 6   0.072052                      (LUNCH BAG DOLLY GIRL DESIGN)
# 7   0.131004                          (LUNCH BAG RED RETROSPOT)
# 8   0.102620                       (LUNCH BAG SPACEBOY DESIGN )
# 9   0.100437                               (LUNCH BAG WOODLAND)
# 10  0.122271                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 11  0.089520                          (MINI PAINT SET VINTAGE )
# 12  0.087336                  (PACK OF 72 RETROSPOT CAKE CASES)
# 13  0.144105                   (PLASTERS IN TIN CIRCUS PARADE )
# ...

# %%
from mlxtend.frequent_patterns import association_rules

# %%
FR_rules = association_rules(FR_frequent_itemsets, metric="lift", min_threshold=1)
FR_rules.head()
# Out:
#                           antecedents  ... conviction
# 0          (PLASTERS IN TIN SPACEBOY)  ...   2.520136
# 1    (PLASTERS IN TIN CIRCUS PARADE )  ...   1.882660
# 2    (PLASTERS IN TIN CIRCUS PARADE )  ...   2.167115
# 3  (PLASTERS IN TIN WOODLAND ANIMALS)  ...   2.123888
# 4          (PLASTERS IN TIN SPACEBOY)  ...   3.770560
#
# [5 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = FR_rules)
plt.show()

# %%
FR_rules[ (FR_rules['lift'] >= 6.4) &
        (FR_rules['confidence'] >= 0.090)]
# Out:
#                                           antecedents  ... conviction
# 6               (SET/20 RED RETROSPOT PAPER NAPKINS )  ...   3.822416
# 7                       (SET/6 RED SPOTTY PAPER CUPS)  ...   3.419214
# 8                     (SET/6 RED SPOTTY PAPER PLATES)  ...   4.432314
# 9               (SET/20 RED RETROSPOT PAPER NAPKINS )  ...   3.860262
# 10                    (SET/6 RED SPOTTY PAPER PLATES)  ...  22.052402
# 11                      (SET/6 RED SPOTTY PAPER CUPS)  ...   8.017467
# 12  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  35.283843
# 13  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...  ...   4.727802
# 14  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...  ...  35.633188
# 15                    (SET/6 RED SPOTTY PAPER PLATES)  ...   4.148472
# 16              (SET/20 RED RETROSPOT PAPER NAPKINS )  ...   3.580786
# 17                      (SET/6 RED SPOTTY PAPER CUPS)  ...   3.285590
#
# [12 rows x 9 columns]

# %%
pivot = FR_rules.pivot(index = 'consequents', columns = 'antecedents', values= 'lift')
sns.heatmap(pivot, annot = True, cbar=False)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()
